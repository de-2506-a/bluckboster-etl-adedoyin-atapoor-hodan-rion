# %% [markdown]
# # Exploratory Data Analysis of Country

# %%
import pandas as pd

# %%
# Create a new DataFrame for country
country_df = pd.read_csv("../data/raw/unclean-country.csv")

# Display first 5 films to verify
country_df.head()
# Out:
#    country_id         country          last_update
# 0           1     Afghanistan  2006-02-15 09:44:00
# 1           2         Algeria  2006-02-15 09:44:00
# 2           3  American Samoa  2006-02-15 09:44:00
# 3           4          Angola  2006-02-15 09:44:00
# 4           5        Anguilla  2006-02-15 09:44:00

# %%
# Check for null values
country_df.isnull().any()
# Out:
# country_id     False
# country        False
# last_update    False
# dtype: bool

# %% [markdown]
# There are no duplicate rows in the films DataFrame so no need for cleaning.

# %%
# Check for any duplicates in the DataFrame
country_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Show the different data types in the country column
country_types = country_df['country'].map(type).unique()
print(f'Different data types in country column: {country_types}')
# Out:
# Different data types in country column: [<class 'str'>]

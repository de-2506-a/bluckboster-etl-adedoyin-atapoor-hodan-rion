# %% [markdown]
# # Exploratory Data Analysis of rental

# %%
import pandas as pd

# %%
# Create a new DataFrame for city
rental_df = pd.read_csv("../data/raw/unclean-rental.csv")

# Display first 5 films to verify
rental_df.head()
# Out:
#    rental_id          rental_date  inventory_id  customer_id  \
# 0          2  2005-05-24 22:54:33          1525          459
# 1          3  2005-05-24 23:03:39          1711          408
# 2          4  2005-05-24 23:04:41          2452          333
# 3          5  2005-05-24 23:05:21          2079          222
# 4          6  2005-05-24 23:08:07          2792          549
#
#            return_date  staff_id          last_update
# 0  2005-05-28 19:40:33         1  2006-02-16 02:30:53
# 1  2005-06-01 22:12:39         1  2006-02-16 02:30:53
# 2  2005-06-03 01:43:41         2  2006-02-16 02:30:53
# 3  2005-06-02 04:33:21         1  2006-02-16 02:30:53
# 4  2005-05-27 01:32:07         1  2006-02-16 02:30:53

# %%
# Check for null values
rental_df.isnull().any()
# Out:
# rental_id       False
# rental_date     False
# inventory_id    False
# customer_id     False
# return_date      True
# staff_id        False
# last_update     False
# dtype: bool

# %%
# Show the different date formats 
unique_date_formats = rental_df['return_date'].unique()
print(f'Different date formats in last_update: {unique_date_formats}')
# Out:
# Different date formats in last_update: ['2005-05-28 19:40:33' '2005-06-01 22:12:39' '2005-06-03 01:43:41' ...
#  '2005-08-31 21:33:07' '2005-08-30 01:01:12' '2005-05-26 22:04:30']

# %%
# Show the different data types in the rental column
rental_types = rental_df['customer_id'].map(type).unique()
print(f'Different data types in release_year column: {rental_types}')
# Out:
# Different data types in release_year column: [<class 'int'>]

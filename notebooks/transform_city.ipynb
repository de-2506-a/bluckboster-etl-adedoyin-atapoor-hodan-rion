# %% [markdown]
# # Exploratory Data Analysis of city

# %%
import pandas as pd

# %%
# Create a new DataFrame for city
city_df = pd.read_csv("../data/raw/unclean-city.csv")

# Display first 5 films to verify
city_df.head()
# Out:
#    city_id                city  country_id
# 0        1  A Corua (La Corua)          87
# 1        2                Abha          82
# 2        3           Abu Dhabi         101
# 3        4                Acua          60
# 4        5               Adana          97

# %%
city_df.isnull().sum()
# Out:
# city_id       0
# city          0
# country_id    0
# dtype: int64

# %%
city_df.isnull().any()
# Out:
# city_id       False
# city          False
# country_id    False
# dtype: bool

# %%
city_df.duplicated().sum()
# Out:
# np.int64(0)

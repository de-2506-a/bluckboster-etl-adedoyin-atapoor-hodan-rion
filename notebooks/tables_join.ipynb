# %% [markdown]
# # Which country has the most customer

# %%
import pandas as pd

# %%
country_df = pd.read_csv("../data/raw/unclean-country.csv")
city_df = pd.read_csv("../data/raw/unclean-city.csv")
customer_df = pd.read_csv("../data/raw/unclean-customers.csv")
rental_df = pd.read_csv("../data/raw/unclean-rental.csv")
inventory_df = pd.read_csv("../data/raw/unclean-inventory.csv")
film_df = pd.read_csv("../data/raw/unclean-films.csv")
address_df = pd.read_csv("../data/raw/unclean-address.csv")

# %%
import pandas as pd

# Step 1: Merge country and city
merged_df = pd.merge(country_df, city_df.drop(columns=["last_update"], errors="ignore"), on="country_id", how="inner")

# Step 2: Merge sequentially with other DataFrames
merged_df = pd.merge(merged_df, address_df.drop(columns=["last_update"], errors="ignore"), on="city_id", how="inner")
merged_df = pd.merge(merged_df, customer_df.drop(columns=["last_update"], errors="ignore"), on="address_id", how="inner")
merged_df = pd.merge(merged_df, rental_df.drop(columns=["last_update"], errors="ignore"), on="customer_id", how="inner")
merged_df = pd.merge(merged_df, inventory_df.drop(columns=["last_update"], errors="ignore"), on="inventory_id", how="inner")
merged_df = pd.merge(merged_df, film_df.drop(columns=["last_update"], errors="ignore"), on="film_id", how="inner")

# Step 3: Aggregate - count customers per country
agg_df = (
    merged_df.groupby("country", as_index=False)
    .agg({"customer_id": "nunique"})
    .rename(columns={"customer_id": "customer_count"})
)

# Step 4: Order results (descending by customer count)
agg_df = agg_df.sort_values(by="customer_count", ascending=False)

print(agg_df)
# Out:
#                   country  customer_count
# 42                  India              60
# 21                  China              52
# 101         United States              35
# 48                  Japan              30
# 58                 Mexico              30
# ..                    ...             ...
# 94                Tunisia               1
# 96           Turkmenistan               1
# 97                 Tuvalu               1
# 104  Virgin Islands, U.S.               1
# 107                Zambia               1
#
# [108 rows x 2 columns]

# %% [markdown]
# # Which film made the most revenue

# %%
import pandas as pd
# Step 1: Merge film and inventory
merged_df = pd.merge(film_df, inventory_df.drop(columns=["last_update"], errors="ignore"), on="film_id", how="inner")
merged_df = pd.merge(merged_df, rental_df.drop(columns=["last_update"], errors="ignore"), on="inventory_id", how="inner")
merged_df = pd.merge(merged_df, payment_df.drop(columns=["last_update"], errors="ignore"), on="rental_id", how="inner")
# Step 3: Aggregate - count customers per country
agg_df = (
    merged_df.groupby("title", as_index=False)
    .agg({"amount": "sum"})
    .rename(columns={"amount": "total_revenue"})
)
# Step 4: Order results (descending by customer count)
agg_df = agg_df.sort_values(by="total_revenue", ascending=False)
print(agg_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 import pandas as pd
#       2 # Step 1: Merge film and inventory
# ----> 3 merged_df = pd.merge(film_df, inventory_df.drop(columns=["last_update"], errors="ignore"), on="film_id", how="inner")
#       4 merged_df = pd.merge(merged_df, rental_df.drop(columns=["last_update"], errors="ignore"), on="inventory_id", how="inner")
#       5 merged_df = pd.merge(merged_df, payment_df.drop(columns=["last_update"], errors="ignore"), on="rental_id", how="inner")
#
# NameError: name 'film_df' is not defined
